# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
# i. Sum of all elements
# ii. Sum of all elements row-wise
# iii. Sum of all elements column-wise

# %%
import numpy as np
gfg=np.matrix('[4,1,9;12,3,1;4,5,6]')
total_sum=np.sum(gfg)
print("sum of elements:",total_sum)
row_sums=np.sum(gfg,axis=1)
print("sum of all rows:",row_sums)
column_sums=np.sum(gfg,axis=0)
print("sum of all column:",column_sums)

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
# i. Sorted array

# %%
import numpy as np
array=np.array([10,52,62,16,16,54,453])
sorted_array=np.sort(array)
print(sorted_array)
# Out:
# [ 10  16  16  52  54  62 453]

# %% [markdown]
# ii. Indices of sorted array

# %%
indices=np.argsort(array)
print(indices)
# Out:
# [0 3 4 1 5 2 6]

# %% [markdown]
# iii. 4 smallest elements

# %%
smallest_4=array[np.argsort(array)[:4]]
print(smallest_4)
# Out:
# [10 16 16 52]

# %% [markdown]
# iv. 5 largest elements

# %%
largest_5=array[np.argsort(array)[-5:]]
print(largest_5)
# Out:
# [ 16  52  54  62 453]

# %% [markdown]
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
# i. Integer elements only
# ii. Float elements only

# %%
import numpy as np
array=np.array([1.0,1.2,2.2,2.0,3.0,2.0])
integer_element=array[array %1==0]
print(integer_element)
# Out:
# [1. 2. 3. 2.]

# %%
float_element =array[array %1!=0]
print(float_element)
# Out:
# [1.2 2.2]

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
# a) Generate your unique sales dataset:
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
#
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#  Use broadcasting to apply this tax rate to each sales value.
# c) Adjust sales based on discount:
#  If sales < X+100, apply a 5% discount.
#  If sales >= X+100, apply a 10% discount.
# d) Expand sales data for multiple weeks:
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
import numpy as np
initials_sum=ord('J')+ord('D')
X=initials_sum
sales=np.array([X,X+50,X+100,X+150,X+200])
tax_rate=((X%5)+5)/100
sales_with_tax=sales*(1+tax_rate)
discount_10_mask=sales_with_tax>=(X+100)
sales_with_tax[discount_10_mask]*=0.90
weekly_sales=np.tile(sales_with_tax,(3,1))
weekly_increase=np.array([1.02,1.04,1.06])
weekly_sales*=weekly_increase[:,np.newaxis]
print("weekly sales date:")
print(weekly_sales)
# Out:
# weekly sales date:
# [[154.9788  209.5488  237.70692 286.81992 335.93292]
#  [158.0176  213.6576  242.36784 292.44384 342.51984]
#  [161.0564  217.7664  247.02876 298.06776 349.10676]]

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)
functions=[lambda x:x**2,
           lambda x:np.sin(x),
           lambda x:np.exp(x),
           lambda x:np.log(np.abs(x)+1)]
functions_names=["Y=x^2",
                "Y=sin(x)",
                "Y=e^x"
                "Y=log(|x|+1)"]
for i, func in enumerate(functions):
    y=func(x)
    plt.figure(figsize=(8,6))
    plt.plot(x,y)
    plt.title(f"plot of{functions_names[i]}")
    plt.xlabel("x")
    plt.ylabel("Y")
    plt.grid(True)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 16
#      14 plt.figure(figsize=(8,6))
#      15 plt.plot(x,y)
# ---> 16 plt.title(f"plot of{functions_names[i]}")
#      17 plt.xlabel("x")
#      18 plt.ylabel("Y")
#
# IndexError: list index out of range
